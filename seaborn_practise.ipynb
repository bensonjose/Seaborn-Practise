# %% [markdown]
# # What is the seaborn used for?
#
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand your data.

# %% [markdown]
# # Why use seaborn and matplotlib?
# Matplotlib and Seaborn are two of the most widely used visualization libraries in Python. They both allow you to quickly perform data visualization for gaining statistical insights and telling a story with data.

# %% [markdown]
# # What is the advantage of seaborn?
# Advantages of seaborn
#
# **It has a concise and expressive syntax that allows users to create complex and customized plots quickly. Additionally, seaborn integrates seamlessly with pandas, the main data manipulation library in Python, and can use pandas data structures as input.**

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
titanic=sns.load_dataset("titanic")
iris=sns.load_dataset("iris")
planets=sns.load_dataset("planets")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="day",size="size",palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'],bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # What does KDE mean in Seaborn?
# kernel density estimate
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram.
#
# ***KDE represents the data using a continuous probability density curve in one or more dimensions.***

# %%
 sns.histplot(tips['tip'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # Displot

# %%
sns.displot(tips["tip"],kde=True,bins=20)

# %% [markdown]
# # Histplot

# %%
sns.histplot(tips["tip"],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # Barplot

# %%
sns.barplot(x="sex",y="tip",data=tips,palette="YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x="day",y="tip",data=tips,hue="sex",palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day",y="tip",data=tips,hue="sex",palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# #
# **dodge seperates the sex**

# %%
sns.stripplot(x="day",y="tip",data=tips,hue="sex",dodge=True,palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Jointplot

# %% [markdown]
# # The Seaborn.jointplot() method
# **is used to subplot grid for plotting pairwise relationships in a dataset. This function offers the JointGrid class a handy interface with a number of pre-made plot types. If you require greater flexibility, you should use JointGrid directly as this wrapper is designed to be relatively lightweight.**
#
# As the name suggests, the Joint Plot is comprised of three individual plots – a bivariate graph that shows the difference of the dependent variable’s behavior with independent variable’s behavior, another plot placed above the bivariate graph to observe the distribution of independent variables, another plot positioned on the right margin vertically that displays the distribution of the dependent variable.

# %%
sns.jointplot(x="tip",y="total_bill",data=tips)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="reg")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="kde",shade=True)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="kde",shade="YlGnBu",cmap="YlGnBu")
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=YlGnBu`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="hex",cmap="YlGnBu")

# %% [markdown]
# # Pairplot

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']),hue="pclass")

# %% [markdown]
# # Heatmap

# %%
titanic.corr()
# Out:
# C:\Users\Bindu\AppData\Local\Temp\ipykernel_6684\2964377706.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
# ...

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="YlGnBu")
# Out:
# C:\Users\Bindu\AppData\Local\Temp\ipykernel_6684\3601765712.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="coolwarm")
# Out:
# C:\Users\Bindu\AppData\Local\Temp\ipykernel_6684\2635739876.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="coolwarm")
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# Out:
# C:\Users\Bindu\AppData\Local\Temp\ipykernel_6684\1269812426.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),annot=True,cmap="icefire")
# <Axes: >
